# %%
#Imports
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.image as img 
from tqdm import tqdm

# %%
classification_garbage = '/Users/augustincablant/Desktop/garbage/classification_garbage'  #clean / test / dirty 
localization_garbage = '/Users/augustincablant/Desktop/garbage/localization_garbage'  #annotations_clean / bases_images / test

# %%
test = img.imread('/Users/augustincablant/Desktop/garbage/classification_garbage/clean/0e02598e-acbb-423e-912e-cf2b922b5bd7.jpeg')
plt.imshow(test)

# %%
test_text = pd.read_xml('/Users/augustincablant/Desktop/garbage/localization_garbage/annotations_clean/k_1.xml')
test_text
# Out:
#    folder  filename  width  height  depth  segmented  truncated  difficult  \
# 0  images      None    NaN     NaN    NaN        NaN        NaN        NaN
# 1    None  k_1.jpeg    NaN     NaN    NaN        NaN        NaN        NaN
# 2    None      None  600.0   419.0    3.0        NaN        NaN        NaN
# 3    None      None    NaN     NaN    NaN        0.0        NaN        NaN
# 4    None      None    NaN     NaN    NaN        NaN        0.0        0.0
# 5    None      None    NaN     NaN    NaN        NaN        0.0        0.0
# 6    None      None    NaN     NaN    NaN        NaN        0.0        0.0
#
#    bndbox
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
