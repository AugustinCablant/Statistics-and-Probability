# %%
import numpy as np 
import scipy 
import scipy.stats as stats 
import matplotlib.pyplot as plt

# %% [markdown]
# # TD1

# %%
1 - stats.poisson.cdf(15,10)
# Out:
# 0.04874040330397866

# %%
1 - stats.poisson.cdf(15,20)
# Out:
# 0.8434868653602571

# %%
stats.poisson.ppf(0.95, 10)
# Out:
# 15.0

# %%
stats.binom.ppf(0.95, 300533, 1 / 310000)
# Out:
# 3.0

# %%
stats.binom.cdf(3, 300533, 1 / 310000)
# Out:
# 0.9828275774334312

# %%
1 - stats.binom.cdf(4, 300533, 1 / 310000)
# Out:
# 0.003212750542870735

# %%
1 - stats.poisson.cdf(4, 300533 / 310000)
# Out:
# 0.0032128187776078176

# %%
1 - stats.gamma.cdf(14.05, 10, 1)
# Out:
# 0.16253452640024268

# %%
stats.gamma.ppf(0.05, 10, 1)
# Out:
# 6.425405697091295

# %%
x = np.arange(0, 35, 0.001)
plt.figure(figsize=(12,8))
plt.scatter(x, stats.poisson.cdf(x, 10), color = 'blue', label = "cdf poisson of parameter 10")
plt.scatter(x, stats.poisson.cdf(x, 20), color = 'red', label = "cdf poisson of parameter 20")
plt.legend()
plt.show()

# %%
expo = stats.expon()

plt.figure(figsize=(8,6))
data = expo.rvs(size=10**5)
plt.hist(data, density=True, label="loi exponentielle")
plt.axvline(x=1, linewidth=3, color="red", label="Moyenne")
plt.legend()
plt.show()

# %%
n = 10
random_state = 123
np.random.seed(random_state)
CVs = []
for _ in range(1_000):
    X = np.random.uniform(size=n)
    X.sort()
    CV = 1 / (12 * n) + np.sum([(X[i-1] - (2 * i - 1) / (2 * n))**2 for i in range(1,n + 1)])
    CVs.append(CV)
plt.figure(figsize=(10,8))
plt.hist(CVs, bins = 30)
plt.show()
